# %%
from requests import Request, Session
from requests.exceptions import ConnectionError, Timeout, TooManyRedirects
import json

url = 'https://pro-api.coinmarketcap.com/v1/cryptocurrency/listings/latest' 
parameters = {
  'start':'1',
  'limit':'15',
  'convert':'USD'
}
headers = {
  'Accepts': 'application/json',
  'X-CMC_PRO_API_KEY': '0ad53085-1cb2-4eb8-ad9e-3ffbd7e56509',
}

session = Session()
session.headers.update(headers)

try:
  response = session.get(url, params=parameters)
  data = json.loads(response.text)
  #print(data)
except (ConnectionError, Timeout, TooManyRedirects) as e:
  print(e)

# %%
type(data)
# Out:
# dict

# %%
import pandas as pd
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)

# %%
df = pd.json_normalize(data['data'])
df['timestamp'] = pd.to_datetime('now')
df
# Out:
#       id             name symbol             slug  num_market_pairs  \
# 0      1          Bitcoin    BTC          bitcoin             10328
# 1   1027         Ethereum    ETH         ethereum              7103
# 2    825           Tether   USDT           tether             56637
# 3   1839              BNB    BNB              bnb              1493
# 4   3408         USD Coin   USDC         usd-coin             13264
# 5     52              XRP    XRP              xrp               979
# 6   2010          Cardano    ADA          cardano               860
# 7     74         Dogecoin   DOGE         dogecoin               740
# 8   5426           Solana    SOL           solana               484
# 9      2         Litecoin    LTC         litecoin               942
# 10  1958             TRON    TRX             tron               785
# 11  3890          Polygon  MATIC          polygon               769
# 12  6636         Polkadot    DOT     polkadot-new               528
# ...

# %%
def api_runner():
    global df
    url = 'https://pro-api.coinmarketcap.com/v1/cryptocurrency/listings/latest' 
    parameters = {
      'start':'1',
      'limit':'15',
      'convert':'USD'
    }
    headers = {
      'Accepts': 'application/json',
      'X-CMC_PRO_API_KEY': '0ad53085-1cb2-4eb8-ad9e-3ffbd7e56509',
    }

    session = Session()
    session.headers.update(headers)

    try:
      response = session.get(url, params=parameters)
      data = json.loads(response.text)
      #print(data)
    except (ConnectionError, Timeout, TooManyRedirects) as e:
      print(e)

    # to create a csv and append data to it
    df = pd.json_normalize(data['data'])
    df['timestamp'] = pd.to_datetime('now')
    df

    if not os.path.isfile(r'C://Users//dell//Data-Anaylsis//Auto-Api.csv'):
        df.to_csv(r'C://Users//dell//Data-Anaylsis//Auto-Api.csv', header='column_names',index=False)
    else:
        df.to_csv(r'C://Users//dell//Data-Anaylsis//Auto-Api.csv', mode='a', header=False)

# %%
import os 
from time import time
from time import sleep

for i in range(300):
    api_runner()
    print('API Runner completed')
    sleep(60) #sleep for 60 sec
exit()
# Out:
# API Runner completed
# API Runner completed
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-25-c3cc43919278> in <module>
#       6     api_runner()
#       7     print('API Runner completed')
# ----> 8     sleep(60) #sleep for 1 minute
#       9 exit()
#
# KeyboardInterrupt:

# %%
df_1 = pd.read_csv(r'C://Users//dell//Data-Anaylsis//Auto-Api.csv')
df_1
# Out:
#     Unnamed: 0    id             name symbol             slug  \
# 0            0     1          Bitcoin    BTC          bitcoin
# 1            1  1027         Ethereum    ETH         ethereum
# 2            2   825           Tether   USDT           tether
# 3            3  1839              BNB    BNB              bnb
# 4            4  3408         USD Coin   USDC         usd-coin
# 5            5    52              XRP    XRP              xrp
# 6            6  2010          Cardano    ADA          cardano
# 7            7    74         Dogecoin   DOGE         dogecoin
# 8            8  5426           Solana    SOL           solana
# 9            9     2         Litecoin    LTC         litecoin
# 10          10  1958             TRON    TRX             tron
# 11          11  3890          Polygon  MATIC          polygon
# 12          12  6636         Polkadot    DOT     polkadot-new
# 13          13  1831     Bitcoin Cash    BCH     bitcoin-cash
# ...

# %%
df
# Out:
#       id             name symbol             slug  num_market_pairs  \
# 0      1          Bitcoin    BTC          bitcoin             10328
# 1   1027         Ethereum    ETH         ethereum              7103
# 2    825           Tether   USDT           tether             56637
# 3   1839              BNB    BNB              bnb              1493
# 4   3408         USD Coin   USDC         usd-coin             13264
# 5     52              XRP    XRP              xrp               979
# 6   2010          Cardano    ADA          cardano               860
# 7     74         Dogecoin   DOGE         dogecoin               740
# 8   5426           Solana    SOL           solana               484
# 9      2         Litecoin    LTC         litecoin               942
# 10  1958             TRON    TRX             tron               785
# 11  3890          Polygon  MATIC          polygon               769
# 12  6636         Polkadot    DOT     polkadot-new               528
# ...

# %%
pd.set_option('display.float_format', lambda x: '%.5f' % x)

# %%
df
# Out:
#       id             name symbol             slug  num_market_pairs  \
# 0      1          Bitcoin    BTC          bitcoin             10328
# 1   1027         Ethereum    ETH         ethereum              7103
# 2    825           Tether   USDT           tether             56637
# 3   1839              BNB    BNB              bnb              1493
# 4   3408         USD Coin   USDC         usd-coin             13264
# 5     52              XRP    XRP              xrp               979
# 6   2010          Cardano    ADA          cardano               860
# 7     74         Dogecoin   DOGE         dogecoin               740
# 8   5426           Solana    SOL           solana               484
# 9      2         Litecoin    LTC         litecoin               942
# 10  1958             TRON    TRX             tron               785
# 11  3890          Polygon  MATIC          polygon               769
# 12  6636         Polkadot    DOT     polkadot-new               528
# ...

# %%
df3 = df.groupby('name', sort=False)[['quote.USD.percent_change_1h','quote.USD.percent_change_24h','quote.USD.percent_change_7d','quote.USD.percent_change_30d','quote.USD.percent_change_60d','quote.USD.percent_change_90d']].mean()
df3
# Out:
#                  quote.USD.percent_change_1h  quote.USD.percent_change_24h  \
# name
# Bitcoin                              0.10068                       0.79793
# Ethereum                            -0.02815                       0.37776
# Tether                              -0.01606                      -0.00047
# BNB                                  0.08823                       1.92174
# USD Coin                            -0.00392                      -0.01215
# XRP                                  0.15079                       0.82865
# Cardano                              0.10635                       1.79284
# Dogecoin                             0.01131                       0.39503
# Solana                               0.74421                       6.41600
# Litecoin                             0.41938                       4.28101
# TRON                                 0.10775                       0.45304
# ...

# %%
df4 = df3.stack()
df4
# Out:
# name
# Bitcoin          quote.USD.percent_change_1h      0.10068
#                  quote.USD.percent_change_24h     0.79793
#                  quote.USD.percent_change_7d     -1.91590
#                  quote.USD.percent_change_30d    18.18328
#                  quote.USD.percent_change_60d    15.19911
#                  quote.USD.percent_change_90d     1.23736
# Ethereum         quote.USD.percent_change_1h     -0.02815
#                  quote.USD.percent_change_24h     0.37776
#                  quote.USD.percent_change_7d     -4.46944
#                  quote.USD.percent_change_30d     6.92525
#                  quote.USD.percent_change_60d     5.59263
#                  quote.USD.percent_change_90d    -0.24460
# Tether           quote.USD.percent_change_1h     -0.01606
#                  quote.USD.percent_change_24h    -0.00047
#                  quote.USD.percent_change_7d     -0.01294
#                  quote.USD.percent_change_30d    -0.03036
# ...

# %%
type(df4)
# Out:
# pandas.core.series.Series

# %%
df5 = df4.to_frame(name='values')
df5
# Out:
#                                                 values
# name
# Bitcoin         quote.USD.percent_change_1h    0.10068
#                 quote.USD.percent_change_24h   0.79793
#                 quote.USD.percent_change_7d   -1.91590
#                 quote.USD.percent_change_30d  18.18328
#                 quote.USD.percent_change_60d  15.19911
#                 quote.USD.percent_change_90d   1.23736
# Ethereum        quote.USD.percent_change_1h   -0.02815
#                 quote.USD.percent_change_24h   0.37776
#                 quote.USD.percent_change_7d   -4.46944
#                 quote.USD.percent_change_30d   6.92525
#                 quote.USD.percent_change_60d   5.59263
#                 quote.USD.percent_change_90d  -0.24460
# Tether          quote.USD.percent_change_1h   -0.01606
#                 quote.USD.percent_change_24h  -0.00047
#                 quote.USD.percent_change_7d   -0.01294
#                 quote.USD.percent_change_30d  -0.03036
# ...

# %%
df5.count()
# Out:
# values    90
# dtype: int64

# %%
index = pd.Index(range(90))
df6 = df5.reset_index()
df6
# Out:
#                name                       level_1    values
# 0           Bitcoin   quote.USD.percent_change_1h   0.10068
# 1           Bitcoin  quote.USD.percent_change_24h   0.79793
# 2           Bitcoin   quote.USD.percent_change_7d  -1.91590
# 3           Bitcoin  quote.USD.percent_change_30d  18.18328
# 4           Bitcoin  quote.USD.percent_change_60d  15.19911
# 5           Bitcoin  quote.USD.percent_change_90d   1.23736
# 6          Ethereum   quote.USD.percent_change_1h  -0.02815
# 7          Ethereum  quote.USD.percent_change_24h   0.37776
# 8          Ethereum   quote.USD.percent_change_7d  -4.46944
# 9          Ethereum  quote.USD.percent_change_30d   6.92525
# 10         Ethereum  quote.USD.percent_change_60d   5.59263
# 11         Ethereum  quote.USD.percent_change_90d  -0.24460
# 12           Tether   quote.USD.percent_change_1h  -0.01606
# 13           Tether  quote.USD.percent_change_24h  -0.00047
# 14           Tether   quote.USD.percent_change_7d  -0.01294
# ...

# %%
df7 = df6.rename(columns={'level_1': 'percent_change'})
df7
# Out:
#                name                percent_change    values
# 0           Bitcoin   quote.USD.percent_change_1h   0.10068
# 1           Bitcoin  quote.USD.percent_change_24h   0.79793
# 2           Bitcoin   quote.USD.percent_change_7d  -1.91590
# 3           Bitcoin  quote.USD.percent_change_30d  18.18328
# 4           Bitcoin  quote.USD.percent_change_60d  15.19911
# 5           Bitcoin  quote.USD.percent_change_90d   1.23736
# 6          Ethereum   quote.USD.percent_change_1h  -0.02815
# 7          Ethereum  quote.USD.percent_change_24h   0.37776
# 8          Ethereum   quote.USD.percent_change_7d  -4.46944
# 9          Ethereum  quote.USD.percent_change_30d   6.92525
# 10         Ethereum  quote.USD.percent_change_60d   5.59263
# 11         Ethereum  quote.USD.percent_change_90d  -0.24460
# 12           Tether   quote.USD.percent_change_1h  -0.01606
# 13           Tether  quote.USD.percent_change_24h  -0.00047
# 14           Tether   quote.USD.percent_change_7d  -0.01294
# ...

# %%
df7['percent_change'] = df7['percent_change'].replace(['quote.USD.percent_change_24h','quote.USD.percent_change_7d','quote.USD.percent_change_30d','quote.USD.percent_change_60d','quote.USD.percent_change_90d'],['24h','7d','30d','60d','90d'])
df7
# Out:
#                name               percent_change    values
# 0           Bitcoin  quote.USD.percent_change_1h   0.10068
# 1           Bitcoin                          24h   0.79793
# 2           Bitcoin                           7d  -1.91590
# 3           Bitcoin                          30d  18.18328
# 4           Bitcoin                          60d  15.19911
# 5           Bitcoin                          90d   1.23736
# 6          Ethereum  quote.USD.percent_change_1h  -0.02815
# 7          Ethereum                          24h   0.37776
# 8          Ethereum                           7d  -4.46944
# 9          Ethereum                          30d   6.92525
# 10         Ethereum                          60d   5.59263
# 11         Ethereum                          90d  -0.24460
# 12           Tether  quote.USD.percent_change_1h  -0.01606
# 13           Tether                          24h  -0.00047
# 14           Tether                           7d  -0.01294
# ...
